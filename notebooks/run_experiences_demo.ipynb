# %%
import os
import sys
import time

import numpy as np
import pandas as pd
import requests

sys.path.append("..")
from api.utils import log_and_raise_for_status

API_URL = "http://localhost:8000"
ALBERT_API_URL = "https://albert.api.etalab.gouv.fr/v1"
ALBERT_API_KEY = os.getenv("ALBERT_API_KEY")

# %%
mfs_dataset = pd.read_csv("_data/evaluation_set_qo_qcm.csv", delimiter=";")
mfs_dataset.rename(columns={'true_answer': 'output_true'}, inplace=True) # to be compliant with EG1
mfs_dataset
# Out:
#                                                 query  \
# 0      Comment contester un PV reçu depuis l’Italie ?
# 1   Quelles aides judiciaires trouver en France po...
# 2   Une mairie peut-elle refuser un formulaire cer...
# 3   Comment renouveler une Carte Nationale d’Ident...
# 4   Quel formulaire cerfa utiliser pour renouveler...
# 5   Peut-on corriger les informations mises sur un...
# 6   La mairie accepte-t-elle de corriger des faute...
# 7   Le fils est né en France et a la nationalité f...
# 8   Comment refaire une carte grise si l’ancien pr...
# 9   Je suis un mineur, qui doit faire la demande d...
# 10  Comment prendre rendez-vous pour faire une dem...
# 11  Comment contester un FPS et quelles sont les é...
# 12  Comment obtenir un passeport ou un visa pour u...
# 13  Comment acheter un timbre fiscal en ligne pour...
# 14  Comment contester une amende d'infraction rout...
# 15  Comment renouveler son passeport en ligne et é...
# 16  Une mairie peut-elle refuser un formulaire pap...
# 17  En quoi consiste l'intermédiation financière d...
# 18  En tant que bénéficiaire d'une pension d'inval...
# 19  Quelles sont les conditions de ressources pour...
# 20        Je change de situation, que dois-je faire ?
# 21  Quel est le pourcentage de prise en charge du ...
# 22  Comment réserver un séjour de vacances et béné...
# 23  Quelles sont les conditions pour toucher une r...
# 24  Comment estimer / simuler sa retraite si vous ...
# 25  Quelles sont les implications d'une faute inex...
# 26                 Comment définit-on l'IPP (MSA) ?\n
# 27  Quelles sont les missions de l'Agence de recou...
# 28  Quand un abattement de 10% est-il mis en place...
# 29  Comment prendre rendez-vous avec l’assurance r...
# 30  Quelles sont les étapes pour préparer sereinem...
# 31            Comment demander sa retraite en ligne ?
# 32  Si vous êtes au régime général de retraite, co...
# 33        Qu’est-ce que la notification de retraite ?
# 34  Quelles sont les conditions pour bénéficier d'...
# 35  À quel âge peut-on prendre sa retraite en Fran...
# 36  Quelle est la procédure pour demander sa pensi...
# 37  Quelle est la date limite pour déposer ma dema...
# 38  Si j'ai des périodes de carrière dans différen...
#
#                                           output_true  top_valid  \
# 0   Pour contester un PV reçu depuis l'Italie, il ...          1
# 1   Vous pouvez bénéficier de l'aide juridictionne...          0
# 2   Non, une mairie ne peut pas refuser un formula...          1
# 3   Pour renouveler une Carte Nationale d'Identité...          1
# 4   Si vous ne faites pas la pré-demande, vous dev...          1
# 5   Non, Une fois validée, la pré-demande ne pourr...          1
# 6   Non, Une fois validée, la pré-demande ne pourr...          1
# 7   Il faut sélectionner : Vous êtes né en France ...          1
# 8   Le vendeur doit faire une déclaration de perte...          1
# 9   pour faire une demande de passeport pour un mi...          1
# 10  Pour prendre rendez-vous afin de faire une dem...          1
# 11  Pour contester un Forfait Post-Stationnement (...          1
# 12  Pour obtenir un passeport ou un visa pour un m...          1
# 13  Pour acheter un timbre fiscal en ligne afin de...          1
# 14  Pour contester, il faut aller sur le site de l...          1
# 15  Pour renouveler son passeport en ligne il faut...          1
# 16  Non, une mairie ne peut pas refuser un formula...          1
# 17   L'intermédiation financière est un dispositif...          1
# 18  En tant que bénéficiaire d'une pension d'inval...          0
# 19  Pour obtenir l'Allocation de Solidarité aux Pe...          0
# 20  If faut déclarer mon changement de situation a...          0
# 21  le pourcentage de prise en charge du coût du s...          0
# 22  Voici les étapes pour réserver un séjour de va...          0
# 23  Voici les principales conditions pour toucher ...          1
# 24  Pour estimer / simulaer sa retraite, il faut u...          1
# 25  La faute inexcusable de l'employeur correspond...          1
# 26  Pour défnir l'IPP (Incapacité Permanente Parti...          1
# 27  L'ARIPA est l'Agence de Recouvrement et d'Inte...          1
# 28  Il n'y a plus d'abattement sur les nouvelles r...          1
# 29  Pour prendre rendez-vous avec l'assurance retr...          1
# 30  pour préparer sereinement son départ à la retr...          1
# 31  Pour faire sa demande de retraite en ligne, il...          1
# 32  En utilisant le service "Demander ma retraite"...          1
# 33  la notification de retraite est le Titre offic...          1
# 34  pour bénéficier d'une retraite anticipée, il f...          1
# 35  L’âge légal de départ à la retraite est de 64 ...          1
# 36   Vous pouvez demander votre retraite en ligne ...          1
# 37  En tant que Fonctionnaire. Je fais ma demande ...          1
# 38   Avant de faire une estimation du montant il f...          1
#
#                      operateur             thematique
# 0                         ANTS                Amendes
# 1                         ANTS                Amendes
# 2                         ANTS          CNI/passeport
# 3                         ANTS          CNI/passeport
# 4                         ANTS          CNI/passeport
# 5                         ANTS          CNI/passeport
# 6                         ANTS          CNI/passeport
# 7                         ANTS          CNI/passeport
# 8   Ministère de l'intérieur ?            Carte grise
# 9                         ANTS          CNI/Passeport
# 10                        ANTS          CNI/Passeport
# 11  Ministère de l'intérieur ?                Amendes
# 12                        ANTS          CNI/passeport
# 13                        ANTS          CNI/passeport
# 14  Ministère de l'intérieur ?                Amendes
# 15                        ANTS          CNI/passeport
# 16                        ANTS          CNI/passeport
# 17                     CAF/MSA  Pensions alimentaires
# 18                     CAF/MSA                    NaN
# 19                     CAF/MSA                    NaN
# 20                     CAF/MSA     Démarches en ligne
# 21                     CAF/MSA                    NaN
# 22                     CAF/MSA                    NaN
# 23                         MSA               Retraite
# 24                         MSA               Retraite
# 25                         MSA                    NaN
# 26                         MSA                    NaN
# 27                     CAF/MSA  Pensions alimentaires
# 28          Assurance retraite               Retraite
# 29          Assurance retraite   Prise de rendez-vous
# 30          Assurance retraite               Retraite
# 31          Assurance retraite     Démarches en ligne
# 32          Assurance retraite     Démarches en ligne
# 33          Assurance retraite               Retraite
# 34          Assurance retraite               Retraite
# 35          Assurance retraite               Retraite
# 36          Assurance retraite               Retraite
# 37          Assurance retraite                    NaN
# 38          Assurance retraite               Retraite

# %%
# Publish a dataset
dataset = {"name": "MFS_questions_v002", "df": mfs_dataset.to_json()}
response = requests.post(f'{API_URL}/v1/dataset', json=dataset)
resp = response.json()
resp
# Out:
# {'name': 'MFS_questions_v002',
#  'id': 25,
#  'has_query': True,
#  'has_output': False,
#  'has_output_true': True,
#  'size': 39}

# %%
# Show available metrics
# - the require fields should be an existing field to the dataset used with the metric.
# - output metric can be generated from the query (see below)
response = requests.get(f'{API_URL}/v1/metrics')
response.json()
# Out:
# [{'name': 'judge_completude',
#   'type': 'llm',
#   'require': ['output', 'output_true']},
#  {'name': 'judge_notator',
#   'type': 'llm',
#   'require': ['output', 'output_true', 'query']},
#  {'name': 'qcm_exactness',
#   'type': 'llm',
#   'require': ['output', 'output_true']},
#  {'name': 'prompt_length', 'type': 'llm', 'require': ['output']},
#  {'name': 'judge_exactness',
#   'type': 'llm',
#   'require': ['output', 'output_true', 'query']}]

# %%
# Launch an experiment with a given **dataset**, **model** and set of **metrics** to compute.
# - the model generate the "output" from the "query"
# - you can also pass the "output" column instead of a model if you generated the answer by yourself...

models_to_test = ["meta-llama/Meta-Llama-3.1-8B-Instruct", "meta-llama/Meta-Llama-3.1-70B-Instruct"]
experiment_ids = []
for i, model in enumerate(models_to_test):
    experiment = {
        "name" : f"MFS_judge_{model}_{i}_v0",
        "dataset": "MFS_questions_v002",
        "model": {"name": model, "base_url": ALBERT_API_URL, "api_key": ALBERT_API_KEY},
        "metrics": ["prompt_length", "judge_exactness", "judge_completude", "judge_notator"],
    }
    response = requests.post(f'{API_URL}/v1/experiment', json=experiment)
    resp = response.json()
    if "id" in resp:
        experiment_ids.append(resp["id"])
        print(f'Experiment {resp["name"]} launched: {resp["experiment_status"]}')
    else:
        print(resp)
# Out:
# Experiment MFS_judge_meta-llama/Meta-Llama-3.1-8B-Instruct_0_v0 launched: running_answers
# Experiment MFS_judge_meta-llama/Meta-Llama-3.1-70B-Instruct_1_v0 launched: running_answers

# %%
# Relaunch measures of an existing experiment
# (FOR THE EXAMPLE)
experiment = {
    "metrics": ["qcm_exactness", "prompt_length"],
    "skip_answers_generation": True,
}
response = requests.patch(f'{API_URL}/v1/experiment/{exp_id}', json=experiment)
response.json()
# Out:
# {'name': 'MFS_judge_v0',
#  'metrics': ['prompt_length',
#   'judge_exactness',
#   'judge_completude',
#   'judge_notator'],
#  'readme': None,
#  'experiment_set_id': None,
#  'skip_answers_generation': True,
#  'id': 6,
#  'created_at': '2024-11-04T00:04:13.568872',
#  'experiment_status': 'running_metrics',
#  'num_try': 39,
#  'num_success': 39,
#  'dataset_id': 10,
#  'model_id': 6}

# %%
# Read results
# --
df_all = []
for model, exp_id in zip(models_to_test, experiment_ids):
    # Get an experiment result
    response = requests.get(f'{API_URL}/v1/experiment/{exp_id}?with_results=true')
    results = response.json()["results"]
    
    # Build a result dataframe
    # --
    # build frontend measure from the observation_table (mean stc etc)
    df_metrics = {}
    for metric_results in results: 
        metric_name = metric_results["metric_name"]
        arr = np.array([x["score"] for x in metric_results["observation_table"] if (isinstance(x["score"], (int, float)))])
        df = pd.DataFrame([[
                np.mean(arr),
                np.std(arr),
                np.median(arr),
                f"{arr.mean():.2f} ± {arr.std():.2f}"  # Formatting as 'mean±std'
            ]], columns=["mean", "std", "median", "mean_std"])
        df_metrics[metric_name] = df
    
    
    # Stack the mean_std final measure
    # --
    # Create a DataFrame for mean±std
    df = pd.DataFrame({metric_name:df["mean_std"].iloc[0] for metric_name, df in df_metrics.items()}, index=[model])
    df_all.append(df)

pd.concat(df_all)
# Out:
#                                           prompt_length judge_completude  \
# meta-llama/Meta-Llama-3.1-8B-Instruct   295.03 ± 107.24    26.67 ± 20.89
# meta-llama/Meta-Llama-3.1-70B-Instruct  242.87 ± 106.95    34.74 ± 23.51
#
#                                        judge_exactness judge_notator
# meta-llama/Meta-Llama-3.1-8B-Instruct      0.08 ± 0.27   3.51 ± 1.99
# meta-llama/Meta-Llama-3.1-70B-Instruct     0.21 ± 0.40   4.79 ± 2.85

# %%
# See what's inside an experiment result
results
# Out:
# [{'metric_name': 'judge_completude',
#   'id': 35,
#   'created_at': '2024-11-04T00:35:36.216793',
#   'observation_table': [{'id': 1167,
#     'created_at': '2024-11-04T00:37:16.344579',
#     'score': 50.0,
#     'observation': '50',
#     'num_line': 8,
#     'error_msg': None},
#    {'id': 1169,
#     'created_at': '2024-11-04T00:37:16.484487',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 4,
#     'error_msg': None},
#    {'id': 1170,
#     'created_at': '2024-11-04T00:37:16.916563',
#     'score': 20.0,
#     'observation': '20',
#     'num_line': 7,
#     'error_msg': None},
#    {'id': 1171,
#     'created_at': '2024-11-04T00:37:16.972361',
#     'score': 20.0,
#     'observation': '20',
#     'num_line': 5,
#     'error_msg': None},
#    {'id': 1173,
#     'created_at': '2024-11-04T00:37:16.919882',
#     'score': 70.0,
#     'observation': '70',
#     'num_line': 3,
#     'error_msg': None},
#    {'id': 1174,
#     'created_at': '2024-11-04T00:37:17.423462',
#     'score': 10.0,
#     'observation': '10',
#     'num_line': 1,
#     'error_msg': None},
#    {'id': 1175,
#     'created_at': '2024-11-04T00:37:16.353679',
#     'score': 20.0,
#     'observation': '20',
#     'num_line': 16,
#     'error_msg': None},
#    {'id': 1176,
#     'created_at': '2024-11-04T00:37:17.743853',
#     'score': 30.0,
#     'observation': '30',
#     'num_line': 0,
#     'error_msg': None},
#    {'id': 1177,
#     'created_at': '2024-11-04T00:37:17.735820',
#     'score': 10.0,
#     'observation': '10',
#     'num_line': 2,
#     'error_msg': None},
#    {'id': 1179,
#     'created_at': '2024-11-04T00:37:17.933052',
#     'score': 80.0,
#     'observation': '80',
#     'num_line': 9,
#     'error_msg': None},
#    {'id': 1180,
#     'created_at': '2024-11-04T00:37:18.007365',
#     'score': 30.0,
#     'observation': '30',
#     'num_line': 13,
#     'error_msg': None},
#    {'id': 1181,
#     'created_at': '2024-11-04T00:37:18.240252',
#     'score': 0.0,
#     'observation': '00',
#     'num_line': 11,
#     'error_msg': None},
#    {'id': 1182,
#     'created_at': '2024-11-04T00:37:18.368288',
#     'score': 50.0,
#     'observation': '50',
#     'num_line': 21,
#     'error_msg': None},
#    {'id': 1183,
#     'created_at': '2024-11-04T00:37:18.356640',
#     'score': 10.0,
#     'observation': '10',
#     'num_line': 19,
#     'error_msg': None},
#    {'id': 1184,
#     'created_at': '2024-11-04T00:37:18.744276',
#     'score': 50.0,
#     'observation': '50',
#     'num_line': 15,
#     'error_msg': None},
#    {'id': 1185,
#     'created_at': '2024-11-04T00:37:18.680236',
#     'score': 60.0,
#     'observation': '60',
#     'num_line': 14,
#     'error_msg': None},
#    {'id': 1186,
#     'created_at': '2024-11-04T00:37:19.088227',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 28,
#     'error_msg': None},
#    {'id': 1187,
#     'created_at': '2024-11-04T00:37:16.333542',
#     'score': 40.0,
#     'observation': '40',
#     'num_line': 18,
#     'error_msg': None},
#    {'id': 1188,
#     'created_at': '2024-11-04T00:37:18.967172',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 20,
#     'error_msg': None},
#    {'id': 1189,
#     'created_at': '2024-11-04T00:37:19.179478',
#     'score': 75.0,
#     'observation': '75',
#     'num_line': 17,
#     'error_msg': None},
#    {'id': 1190,
#     'created_at': '2024-11-04T00:37:19.644833',
#     'score': 70.0,
#     'observation': '70',
#     'num_line': 27,
#     'error_msg': None},
#    {'id': 1191,
#     'created_at': '2024-11-04T00:37:19.608774',
#     'score': 50.0,
#     'observation': '50',
#     'num_line': 23,
#     'error_msg': None},
#    {'id': 1192,
#     'created_at': '2024-11-04T00:37:19.685549',
#     'score': 30.0,
#     'observation': '30',
#     'num_line': 38,
#     'error_msg': None},
#    {'id': 1193,
#     'created_at': '2024-11-04T00:37:19.993706',
#     'score': 50.0,
#     'observation': '50',
#     'num_line': 29,
#     'error_msg': None},
#    {'id': 1194,
#     'created_at': '2024-11-04T00:37:20.313942',
#     'score': 30.0,
#     'observation': '30',
#     'num_line': 32,
#     'error_msg': None},
#    {'id': 1195,
#     'created_at': '2024-11-04T00:37:20.803323',
#     'score': 30.0,
#     'observation': '30',
#     'num_line': 31,
#     'error_msg': None},
#    {'id': 1196,
#     'created_at': '2024-11-04T00:37:21.208895',
#     'score': 50.0,
#     'observation': '50',
#     'num_line': 37,
#     'error_msg': None},
#    {'id': 1197,
#     'created_at': '2024-11-04T00:37:19.992431',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 26,
#     'error_msg': None},
#    {'id': 1198,
#     'created_at': '2024-11-04T00:37:22.235807',
#     'score': 30.0,
#     'observation': '30',
#     'num_line': 22,
#     'error_msg': None},
#    {'id': 1199,
#     'created_at': '2024-11-04T00:37:22.789298',
#     'score': 30.0,
#     'observation': '30',
#     'num_line': 34,
#     'error_msg': None},
#    {'id': 1200,
#     'created_at': '2024-11-04T00:37:23.312166',
#     'score': 30.0,
#     'observation': '30',
#     'num_line': 33,
#     'error_msg': None},
#    {'id': 1201,
#     'created_at': '2024-11-04T00:37:20.403711',
#     'score': 20.0,
#     'observation': '20',
#     'num_line': 24,
#     'error_msg': None},
#    {'id': 1203,
#     'created_at': '2024-11-04T00:37:17.429533',
#     'score': 10.0,
#     'observation': '10',
#     'num_line': 6,
#     'error_msg': None},
#    {'id': 1204,
#     'created_at': '2024-11-04T00:37:23.825386',
#     'score': 20.0,
#     'observation': '20',
#     'num_line': 35,
#     'error_msg': None},
#    {'id': 1205,
#     'created_at': '2024-11-04T00:37:24.228258',
#     'score': 20.0,
#     'observation': '20',
#     'num_line': 30,
#     'error_msg': None},
#    {'id': 1208,
#     'created_at': '2024-11-04T00:37:19.194360',
#     'score': 50.0,
#     'observation': '50',
#     'num_line': 25,
#     'error_msg': None},
#    {'id': 1214,
#     'created_at': '2024-11-04T00:37:21.825013',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 12,
#     'error_msg': None},
#    {'id': 1228,
#     'created_at': '2024-11-04T00:37:18.667307',
#     'score': 30.0,
#     'observation': '30',
#     'num_line': 10,
#     'error_msg': None},
#    {'id': 1247,
#     'created_at': '2024-11-04T00:37:19.575174',
#     'score': 20.0,
#     'observation': '20',
#     'num_line': 36,
#     'error_msg': None}],
#   'num_try': 39,
#   'num_success': 39,
#   'experiment_id': 9},
#  {'metric_name': 'judge_notator',
#   'id': 36,
#   'created_at': '2024-11-04T00:35:36.216793',
#   'observation_table': [{'id': 1206,
#     'created_at': '2024-11-04T00:37:24.265735',
#     'score': 7.0,
#     'observation': '7',
#     'num_line': 8,
#     'error_msg': None},
#    {'id': 1207,
#     'created_at': '2024-11-04T00:37:24.319663',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 16,
#     'error_msg': None},
#    {'id': 1209,
#     'created_at': '2024-11-04T00:37:24.593137',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 4,
#     'error_msg': None},
#    {'id': 1210,
#     'created_at': '2024-11-04T00:37:24.840378',
#     'score': 9.0,
#     'observation': '9',
#     'num_line': 3,
#     'error_msg': None},
#    {'id': 1217,
#     'created_at': '2024-11-04T00:37:25.335744',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 6,
#     'error_msg': None},
#    {'id': 1224,
#     'created_at': '2024-11-04T00:37:25.914667',
#     'score': 5.0,
#     'observation': '5',
#     'num_line': 21,
#     'error_msg': None},
#    {'id': 1227,
#     'created_at': '2024-11-04T00:37:26.433812',
#     'score': 8.0,
#     'observation': '8',
#     'num_line': 17,
#     'error_msg': None},
#    {'id': 1231,
#     'created_at': '2024-11-04T00:37:26.973529',
#     'score': 6.0,
#     'observation': '6',
#     'num_line': 27,
#     'error_msg': None},
#    {'id': 1236,
#     'created_at': '2024-11-04T00:37:27.454578',
#     'score': 7.0,
#     'observation': '7',
#     'num_line': 32,
#     'error_msg': None},
#    {'id': 1240,
#     'created_at': '2024-11-04T00:37:28.036305',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 22,
#     'error_msg': None},
#    {'id': 1244,
#     'created_at': '2024-11-04T00:37:28.466183',
#     'score': 3.0,
#     'observation': '3',
#     'num_line': 35,
#     'error_msg': None},
#    {'id': 1211,
#     'created_at': '2024-11-04T00:37:24.779357',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 7,
#     'error_msg': None},
#    {'id': 1215,
#     'created_at': '2024-11-04T00:37:25.341105',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 2,
#     'error_msg': None},
#    {'id': 1221,
#     'created_at': '2024-11-04T00:37:25.848992',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 11,
#     'error_msg': None},
#    {'id': 1248,
#     'created_at': '2024-11-04T00:37:26.355542',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 20,
#     'error_msg': None},
#    {'id': 1212,
#     'created_at': '2024-11-04T00:37:24.953224',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 5,
#     'error_msg': None},
#    {'id': 1216,
#     'created_at': '2024-11-04T00:37:25.462391',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 0,
#     'error_msg': None},
#    {'id': 1220,
#     'created_at': '2024-11-04T00:37:25.872209',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 19,
#     'error_msg': None},
#    {'id': 1225,
#     'created_at': '2024-11-04T00:37:26.352708',
#     'score': 7.0,
#     'observation': '7',
#     'num_line': 15,
#     'error_msg': None},
#    {'id': 1229,
#     'created_at': '2024-11-04T00:37:26.898724',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 36,
#     'error_msg': None},
#    {'id': 1246,
#     'created_at': '2024-11-04T00:37:27.368282',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 26,
#     'error_msg': None},
#    {'id': 1213,
#     'created_at': '2024-11-04T00:37:24.999290',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 1,
#     'error_msg': None},
#    {'id': 1218,
#     'created_at': '2024-11-04T00:37:25.507735',
#     'score': 9.0,
#     'observation': '9',
#     'num_line': 9,
#     'error_msg': None},
#    {'id': 1223,
#     'created_at': '2024-11-04T00:37:25.987262',
#     'score': 5.0,
#     'observation': '5',
#     'num_line': 10,
#     'error_msg': None},
#    {'id': 1241,
#     'created_at': '2024-11-04T00:37:26.436973',
#     'score': 6.0,
#     'observation': '6',
#     'num_line': 25,
#     'error_msg': None},
#    {'id': 1219,
#     'created_at': '2024-11-04T00:37:25.586175',
#     'score': 3.0,
#     'observation': '3',
#     'num_line': 13,
#     'error_msg': None},
#    {'id': 1232,
#     'created_at': '2024-11-04T00:37:26.023017',
#     'score': 6.0,
#     'observation': '6',
#     'num_line': 14,
#     'error_msg': None},
#    {'id': 1234,
#     'created_at': '2024-11-04T00:37:27.486012',
#     'score': 6.0,
#     'observation': '6',
#     'num_line': 24,
#     'error_msg': None},
#    {'id': 1237,
#     'created_at': '2024-11-04T00:37:27.806175',
#     'score': 6.0,
#     'observation': '6',
#     'num_line': 37,
#     'error_msg': None},
#    {'id': 1245,
#     'created_at': '2024-11-04T00:37:28.396965',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 34,
#     'error_msg': None},
#    {'id': 1222,
#     'created_at': '2024-11-04T00:37:24.258637',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 18,
#     'error_msg': None},
#    {'id': 1226,
#     'created_at': '2024-11-04T00:37:26.433866',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 28,
#     'error_msg': None},
#    {'id': 1230,
#     'created_at': '2024-11-04T00:37:26.917663',
#     'score': 5.0,
#     'observation': '5',
#     'num_line': 23,
#     'error_msg': None},
#    {'id': 1235,
#     'created_at': '2024-11-04T00:37:27.408189',
#     'score': 6.0,
#     'observation': '6',
#     'num_line': 29,
#     'error_msg': None},
#    {'id': 1239,
#     'created_at': '2024-11-04T00:37:27.906788',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 12,
#     'error_msg': None},
#    {'id': 1243,
#     'created_at': '2024-11-04T00:37:28.467567',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 30,
#     'error_msg': None},
#    {'id': 1233,
#     'created_at': '2024-11-04T00:37:27.262646',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 38,
#     'error_msg': None},
#    {'id': 1238,
#     'created_at': '2024-11-04T00:37:27.761581',
#     'score': 4.0,
#     'observation': '4',
#     'num_line': 31,
#     'error_msg': None},
#    {'id': 1242,
#     'created_at': '2024-11-04T00:37:28.402054',
#     'score': 3.0,
#     'observation': '3',
#     'num_line': 33,
#     'error_msg': None}],
#   'num_try': 39,
#   'num_success': 39,
#   'experiment_id': 9},
#  {'metric_name': 'prompt_length',
#   'id': 33,
#   'created_at': '2024-11-04T00:35:36.216793',
#   'observation_table': [{'id': 1092,
#     'created_at': '2024-11-04T00:37:12.333266',
#     'score': 407.0,
#     'observation': None,
#     'num_line': 18,
#     'error_msg': None},
#    {'id': 1093,
#     'created_at': '2024-11-04T00:37:12.338509',
#     'score': 192.0,
#     'observation': None,
#     'num_line': 8,
#     'error_msg': None},
#    {'id': 1094,
#     'created_at': '2024-11-04T00:37:12.342842',
#     'score': 173.0,
#     'observation': None,
#     'num_line': 16,
#     'error_msg': None},
#    {'id': 1095,
#     'created_at': '2024-11-04T00:37:12.345311',
#     'score': 211.0,
#     'observation': None,
#     'num_line': 7,
#     'error_msg': None},
#    {'id': 1096,
#     'created_at': '2024-11-04T00:37:12.371946',
#     'score': 15.0,
#     'observation': None,
#     'num_line': 4,
#     'error_msg': None},
#    {'id': 1097,
#     'created_at': '2024-11-04T00:37:12.406760',
#     'score': 293.0,
#     'observation': None,
#     'num_line': 3,
#     'error_msg': None},
#    {'id': 1098,
#     'created_at': '2024-11-04T00:37:12.444736',
#     'score': 340.0,
#     'observation': None,
#     'num_line': 5,
#     'error_msg': None},
#    {'id': 1099,
#     'created_at': '2024-11-04T00:37:12.447777',
#     'score': 295.0,
#     'observation': None,
#     'num_line': 1,
#     'error_msg': None},
#    {'id': 1100,
#     'created_at': '2024-11-04T00:37:12.475936',
#     'score': 276.0,
#     'observation': None,
#     'num_line': 2,
#     'error_msg': None},
#    {'id': 1101,
#     'created_at': '2024-11-04T00:37:12.472886',
#     'score': 226.0,
#     'observation': None,
#     'num_line': 6,
#     'error_msg': None},
#    {'id': 1102,
#     'created_at': '2024-11-04T00:37:12.543606',
#     'score': 392.0,
#     'observation': None,
#     'num_line': 0,
#     'error_msg': None},
#    {'id': 1103,
#     'created_at': '2024-11-04T00:37:12.602857',
#     'score': 182.0,
#     'observation': None,
#     'num_line': 9,
#     'error_msg': None},
#    {'id': 1104,
#     'created_at': '2024-11-04T00:37:12.598084',
#     'score': 117.0,
#     'observation': None,
#     'num_line': 13,
#     'error_msg': None},
#    {'id': 1105,
#     'created_at': '2024-11-04T00:37:12.634186',
#     'score': 234.0,
#     'observation': None,
#     'num_line': 11,
#     'error_msg': None},
#    {'id': 1106,
#     'created_at': '2024-11-04T00:37:12.647362',
#     'score': 60.0,
#     'observation': None,
#     'num_line': 19,
#     'error_msg': None},
#    {'id': 1107,
#     'created_at': '2024-11-04T00:37:12.670190',
#     'score': 299.0,
#     'observation': None,
#     'num_line': 10,
#     'error_msg': None},
#    {'id': 1108,
#     'created_at': '2024-11-04T00:37:12.669115',
#     'score': 82.0,
#     'observation': None,
#     'num_line': 21,
#     'error_msg': None},
#    {'id': 1109,
#     'created_at': '2024-11-04T00:37:12.698460',
#     'score': 249.0,
#     'observation': None,
#     'num_line': 14,
#     'error_msg': None},
#    {'id': 1110,
#     'created_at': '2024-11-04T00:37:12.732101',
#     'score': 258.0,
#     'observation': None,
#     'num_line': 15,
#     'error_msg': None},
#    {'id': 1111,
#     'created_at': '2024-11-04T00:37:12.734782',
#     'score': 289.0,
#     'observation': None,
#     'num_line': 20,
#     'error_msg': None},
#    {'id': 1112,
#     'created_at': '2024-11-04T00:37:12.759375',
#     'score': 16.0,
#     'observation': None,
#     'num_line': 28,
#     'error_msg': None},
#    {'id': 1113,
#     'created_at': '2024-11-04T00:37:12.770826',
#     'score': 209.0,
#     'observation': None,
#     'num_line': 17,
#     'error_msg': None},
#    {'id': 1114,
#     'created_at': '2024-11-04T00:37:12.780463',
#     'score': 354.0,
#     'observation': None,
#     'num_line': 25,
#     'error_msg': None},
#    {'id': 1115,
#     'created_at': '2024-11-04T00:37:12.802670',
#     'score': 282.0,
#     'observation': None,
#     'num_line': 36,
#     'error_msg': None},
#    {'id': 1116,
#     'created_at': '2024-11-04T00:37:12.811346',
#     'score': 213.0,
#     'observation': None,
#     'num_line': 23,
#     'error_msg': None},
#    {'id': 1117,
#     'created_at': '2024-11-04T00:37:12.831107',
#     'score': 215.0,
#     'observation': None,
#     'num_line': 27,
#     'error_msg': None},
#    {'id': 1118,
#     'created_at': '2024-11-04T00:37:12.852262',
#     'score': 188.0,
#     'observation': None,
#     'num_line': 26,
#     'error_msg': None},
#    {'id': 1119,
#     'created_at': '2024-11-04T00:37:12.864844',
#     'score': 12.0,
#     'observation': None,
#     'num_line': 29,
#     'error_msg': None},
#    {'id': 1120,
#     'created_at': '2024-11-04T00:37:12.850831',
#     'score': 386.0,
#     'observation': None,
#     'num_line': 38,
#     'error_msg': None},
#    {'id': 1121,
#     'created_at': '2024-11-04T00:37:12.891459',
#     'score': 324.0,
#     'observation': None,
#     'num_line': 32,
#     'error_msg': None},
#    {'id': 1122,
#     'created_at': '2024-11-04T00:37:12.912801',
#     'score': 160.0,
#     'observation': None,
#     'num_line': 31,
#     'error_msg': None},
#    {'id': 1123,
#     'created_at': '2024-11-04T00:37:12.901048',
#     'score': 250.0,
#     'observation': None,
#     'num_line': 24,
#     'error_msg': None},
#    {'id': 1124,
#     'created_at': '2024-11-04T00:37:12.928544',
#     'score': 288.0,
#     'observation': None,
#     'num_line': 37,
#     'error_msg': None},
#    {'id': 1125,
#     'created_at': '2024-11-04T00:37:12.962446',
#     'score': 279.0,
#     'observation': None,
#     'num_line': 22,
#     'error_msg': None},
#    {'id': 1126,
#     'created_at': '2024-11-04T00:37:12.981460',
#     'score': 280.0,
#     'observation': None,
#     'num_line': 34,
#     'error_msg': None},
#    {'id': 1127,
#     'created_at': '2024-11-04T00:37:13.002453',
#     'score': None,
#     'observation': None,
#     'num_line': 12,
#     'error_msg': "Observation prompt_length failed with error: 'NoneType' object has no attribute 'split'"},
#    {'id': 1128,
#     'created_at': '2024-11-04T00:37:13.012559',
#     'score': 206.0,
#     'observation': None,
#     'num_line': 35,
#     'error_msg': None},
#    {'id': 1129,
#     'created_at': '2024-11-04T00:37:13.010759',
#     'score': 151.0,
#     'observation': None,
#     'num_line': 33,
#     'error_msg': None},
#    {'id': 1130,
#     'created_at': '2024-11-04T00:37:13.018636',
#     'score': 319.0,
#     'observation': None,
#     'num_line': 30,
#     'error_msg': None}],
#   'num_try': 39,
#   'num_success': 38,
#   'experiment_id': 9},
#  {'metric_name': 'judge_exactness',
#   'id': 34,
#   'created_at': '2024-11-04T00:35:36.216793',
#   'observation_table': [{'id': 1131,
#     'created_at': '2024-11-04T00:37:13.080326',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 16,
#     'error_msg': None},
#    {'id': 1132,
#     'created_at': '2024-11-04T00:37:13.105223',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 3,
#     'error_msg': None},
#    {'id': 1133,
#     'created_at': '2024-11-04T00:37:13.096027',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 7,
#     'error_msg': None},
#    {'id': 1134,
#     'created_at': '2024-11-04T00:37:13.092385',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 4,
#     'error_msg': None},
#    {'id': 1135,
#     'created_at': '2024-11-04T00:37:13.072172',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 8,
#     'error_msg': None},
#    {'id': 1136,
#     'created_at': '2024-11-04T00:37:13.156618',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 5,
#     'error_msg': None},
#    {'id': 1137,
#     'created_at': '2024-11-04T00:37:13.743172',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 0,
#     'error_msg': None},
#    {'id': 1138,
#     'created_at': '2024-11-04T00:37:13.767655',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 13,
#     'error_msg': None},
#    {'id': 1139,
#     'created_at': '2024-11-04T00:37:13.664765',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 1,
#     'error_msg': None},
#    {'id': 1140,
#     'created_at': '2024-11-04T00:37:13.021427',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 18,
#     'error_msg': None},
#    {'id': 1141,
#     'created_at': '2024-11-04T00:37:13.711312',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 2,
#     'error_msg': None},
#    {'id': 1142,
#     'created_at': '2024-11-04T00:37:13.746221',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 9,
#     'error_msg': None},
#    {'id': 1143,
#     'created_at': '2024-11-04T00:37:14.219934',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 19,
#     'error_msg': None},
#    {'id': 1144,
#     'created_at': '2024-11-04T00:37:14.144823',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 11,
#     'error_msg': None},
#    {'id': 1145,
#     'created_at': '2024-11-04T00:37:14.221149',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 21,
#     'error_msg': None},
#    {'id': 1147,
#     'created_at': '2024-11-04T00:37:14.366587',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 10,
#     'error_msg': None},
#    {'id': 1148,
#     'created_at': '2024-11-04T00:37:13.709880',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 6,
#     'error_msg': None},
#    {'id': 1149,
#     'created_at': '2024-11-04T00:37:14.511137',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 15,
#     'error_msg': None},
#    {'id': 1150,
#     'created_at': '2024-11-04T00:37:14.479157',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 14,
#     'error_msg': None},
#    {'id': 1151,
#     'created_at': '2024-11-04T00:37:14.742649',
#     'score': 1.0,
#     'observation': '1',
#     'num_line': 17,
#     'error_msg': None},
#    {'id': 1152,
#     'created_at': '2024-11-04T00:37:14.797878',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 36,
#     'error_msg': None},
#    {'id': 1153,
#     'created_at': '2024-11-04T00:37:14.701110',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 28,
#     'error_msg': None},
#    {'id': 1154,
#     'created_at': '2024-11-04T00:37:14.843965',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 23,
#     'error_msg': None},
#    {'id': 1155,
#     'created_at': '2024-11-04T00:37:14.944202',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 27,
#     'error_msg': None},
#    {'id': 1156,
#     'created_at': '2024-11-04T00:37:14.660418',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 20,
#     'error_msg': None},
#    {'id': 1157,
#     'created_at': '2024-11-04T00:37:15.351953',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 24,
#     'error_msg': None},
#    {'id': 1158,
#     'created_at': '2024-11-04T00:37:15.302344',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 38,
#     'error_msg': None},
#    {'id': 1159,
#     'created_at': '2024-11-04T00:37:15.317355',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 29,
#     'error_msg': None},
#    {'id': 1160,
#     'created_at': '2024-11-04T00:37:15.342906',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 32,
#     'error_msg': None},
#    {'id': 1161,
#     'created_at': '2024-11-04T00:37:15.434162',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 31,
#     'error_msg': None},
#    {'id': 1162,
#     'created_at': '2024-11-04T00:37:15.804667',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 22,
#     'error_msg': None},
#    {'id': 1163,
#     'created_at': '2024-11-04T00:37:15.797384',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 37,
#     'error_msg': None},
#    {'id': 1164,
#     'created_at': '2024-11-04T00:37:15.903217',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 33,
#     'error_msg': None},
#    {'id': 1165,
#     'created_at': '2024-11-04T00:37:15.802874',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 12,
#     'error_msg': None},
#    {'id': 1166,
#     'created_at': '2024-11-04T00:37:15.983411',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 35,
#     'error_msg': None},
#    {'id': 1168,
#     'created_at': '2024-11-04T00:37:16.331285',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 30,
#     'error_msg': None},
#    {'id': 1172,
#     'created_at': '2024-11-04T00:37:14.763840',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 25,
#     'error_msg': None},
#    {'id': 1178,
#     'created_at': '2024-11-04T00:37:15.853649',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 34,
#     'error_msg': None},
#    {'id': 1202,
#     'created_at': '2024-11-04T00:37:15.315324',
#     'score': 0.0,
#     'observation': '0',
#     'num_line': 26,
#     'error_msg': None}],
#   'num_try': 39,
#   'num_success': 39,
#   'experiment_id': 9}]
